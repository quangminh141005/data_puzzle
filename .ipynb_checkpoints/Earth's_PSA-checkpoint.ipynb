# %%
import pandas as pd

# %%
countries = ['Guinea', 'Iran', 'Trinidad and Tobago', 'Honduras', 'Lebanon',
             'Ethiopia', 'Niger', 'Afghanistan', 'India', 'American Samoa',
             'Cuba', 'Gabon', 'Nicaragua', 'Channel Islands', 'Martinique']

country_pop = pd.read_csv('https://raw.githubusercontent.com/hyperc54/data-puzzles-assets/master/misc/earth/population_by_country.csv')

# %%
country_surface = pd.read_csv('https://raw.githubusercontent.com/hyperc54/data-puzzles-assets/master/misc/earth/surface_by_country.csv')

# %% [markdown]
# Merge 2 databases together

# %%
countries_merge = country_pop.merge(country_surface, on='Country (or dependency)')
print(countries_merge)
# Out:
#     Country (or dependency)  Population (2020) Yearly Change Urban Pop %  \
# 0                     China         1440297825        0.39 %        61 %
# 1                     India         1382345085        0.99 %        35 %
# 2             United States          331341050        0.59 %        83 %
# 3                 Indonesia          274021604        1.07 %        56 %
# 4                  Pakistan          221612785        2.00 %        35 %
# ..                      ...                ...           ...         ...
# 230              Montserrat               4993        0.06 %        10 %
# 231        Falkland Islands               3497        3.05 %        66 %
# 232                    Niue               1628        0.68 %        46 %
# 233                 Tokelau               1360        1.27 %         0 %
# 234                Holy See                801        0.25 %        N.A.
#
#     World Share  Land Area (Km²)
# 0       18.47 %          9388211
# ...

# %%
countries_merge = countries_merge[countries_merge['Country (or dependency)'].isin(countries)]

# %% [markdown]
# After merging two database together, calculating population density

# %%
print(countries_merge)
# Out:
#     Country (or dependency)  Population (2020) Yearly Change Urban Pop %  \
# 1                     India         1382345085        0.99 %        35 %
# 11                 Ethiopia          115434444        2.57 %        21 %
# 17                     Iran           84176929        1.30 %        76 %
# 36              Afghanistan           39074280        2.33 %        25 %
# 55                    Niger           24346468        3.84 %        17 %
# 74                   Guinea           13191279        2.83 %        39 %
# 82                     Cuba           11325391       -0.06 %        78 %
# 91                 Honduras            9931333        1.63 %        57 %
# 108                 Lebanon            6819976       -0.44 %        78 %
# 109               Nicaragua            6638075        1.21 %        57 %
# 145                   Gabon            2234448        2.45 %        87 %
# 153     Trinidad and Tobago            1400283        0.32 %        52 %
# ...

# %%
countries_merge['pop_density'] = countries_merge['Population (2020)'] / countries_merge['Land Area (Km²)']

# %%
countries_merge = countries_merge.sort_values(by=['pop_density'], ascending=False)
print(countries_merge)
# Out:
#     Country (or dependency)  Population (2020) Yearly Change Urban Pop %  \
# 189         Channel Islands             174140        0.93 %        30 %
# 108                 Lebanon            6819976       -0.44 %        78 %
# 1                     India         1382345085        0.99 %        35 %
# 178              Martinique             375213       -0.08 %        92 %
# 209          American Samoa              55169       -0.22 %        88 %
# 153     Trinidad and Tobago            1400283        0.32 %        52 %
# 11                 Ethiopia          115434444        2.57 %        21 %
# 82                     Cuba           11325391       -0.06 %        78 %
# 91                 Honduras            9931333        1.63 %        57 %
# 36              Afghanistan           39074280        2.33 %        25 %
# 109               Nicaragua            6638075        1.21 %        57 %
# 74                   Guinea           13191279        2.83 %        39 %
# ...

# %%
first_word = countries_merge['Country (or dependency)'].apply(lambda x:x[0])
''.join(list(first_word))
# Out:
# 'CLIMATECHANGING'
